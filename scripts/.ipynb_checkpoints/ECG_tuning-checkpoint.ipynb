# %%
from ECG_helpers_tf import *
# Out:
# Using TensorFlow backend.

# %%
#take command input
#if(len(sys.argv)==1): #default job
if(True): #default job
    target = 'Sex'
    random_seed_hyperparameters = 0
else:
    target = sys.argv[1] #available: 'Age', 'Sex'
    random_seed_hyperparameters = sys.argv[2]

# %%
#hyperparameters
n_epochs=10
hyperparameters ={}
hyperparameters['batch_size'] = 1024
random.seed(random_seed_hyperparameters)
for hyperparameter in hyperparameters_tuned:
    hyperparameters[hyperparameter] = random.choice(hyperparameters_tuned_lists[hyperparameter])
print(hyperparameters)
random.seed(0) #reset random seed
# Out:
# {'batch_size': 1024, 'model_type': 'GRU', 'n_layers': 8, 'n_nodes': 4, 'optimizer': 'RMSprop', 'learning_rate': 1e-05, 'resize_factor': 60}

# %%
#load data
for fold in folds:
    globals()['demo_'+fold] = pd.read_csv(path_store + 'demo_' + fold + '.csv', header=0, index_col=0)
    globals()['y_'+fold] = globals()['demo_'+fold][target]
    globals()['X_'+fold] = np.load(path_store + 'X_' + fold + '.npy') #.astype(float) did not make a difference

# %%
#scale input: find max for each lead over the training set
maxes_leads = np.abs(X_train.max(axis=(0,1)))
for fold in folds:
    globals()['X_'+fold] = globals()['X_'+fold]/maxes_leads
#resize data   
for fold in folds:
    globals()['X_'+fold] = resize_X_by_timesteps(globals()['X_'+fold], hyperparameters['resize_factor'])
#scale target if predicting Age (should not make a difference)
if target == 'Age':
    max_target = np.max(y_train)
    min_target = np.min(y_train)
    for fold in folds:
        globals()['y_'+fold] = (globals()['y_'+fold]-min_target)/(max_target-min_target)

# %%
#build model
model = generate_model(hyperparameters['model_type'], hyperparameters['n_layers'], hyperparameters['n_nodes'], target, hyperparameters['resize_factor'], X_train)
opt = globals()[hyperparameters['optimizer']](lr=hyperparameters['learning_rate'])
model.compile(optimizer=opt, loss=dict_loss[target], metrics=[dict_metrics_functions[target] for target in dict_metrics[target]])
# Out:
# WARNING:tensorflow:From /home/al311/python_3.6.0/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
#train model
hyperparameters['n_epochs_run'] = 0
Best_performance = -inf
no_improvement = 0
while(no_improvement < 5):
    history = model.fit(X_train, np.array(y_train), epochs=n_epochs, batch_size=hyperparameters['batch_size'], validation_data=[X_val,np.array(y_val)])
    hyperparameters['n_epochs_run'] += n_epochs
    version = target + '_' + hyperparameters['model_type'] + '_n_layers_' + str(hyperparameters['n_layers']) + '_n_nodes_' + str(hyperparameters['n_nodes']) + '_optimizer_' + hyperparameters['optimizer'] + '_learning_rate_' + str(int(-np.log10(hyperparameters['learning_rate']))) + '_input_length_' + str(int(600/hyperparameters['resize_factor'])) + '_batch_size_' + str(hyperparameters['batch_size']) + '_n_epochs_run_' + str(hyperparameters['n_epochs_run'])
    print('Number of epochs run: ' + str(hyperparameters['n_epochs_run']))
    print('Version: ' + version)
    plot_training(history, target, hyperparameters, version, n_epochs)
    generate_predictions_and_compute_performances(model, hyperparameters, X_train, X_val, X_test, y_train, y_val, y_test, target, version)
    if hyperparameters['Performance_val'] > Best_performance:
        Best_performance = hyperparameters['Performance_val']
        print('The performance improved. New best performance = ' + str(Best_performance))
    else:
        no_improvement += 1
        print('The performance did not improve for ' + str(no_improvement) + 'session(s)')
print('Stopping the training. The validation accuracy is unlikely to further improve.')
# Out:
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 180us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 178us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 178us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Number of epochs run: 3
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_3
# Performance on the train set is equal to: 0.699
# Performance on the val set is equal to: 0.713
# Performance on the test set is equal to: 0.683
# The performance improved. New best performance = 0.713
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 180us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 178us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 178us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Number of epochs run: 6
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_6
# Performance on the train set is equal to: 0.699
# Performance on the val set is equal to: 0.713
# Performance on the test set is equal to: 0.684
# The performance improved. New best performance = 0.713
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 180us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 181us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Number of epochs run: 9
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_9
# Performance on the train set is equal to: 0.699
# Performance on the val set is equal to: 0.713
# Performance on the test set is equal to: 0.684
# The performance improved. New best performance = 0.713
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 178us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Number of epochs run: 12
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_12
# Performance on the train set is equal to: 0.699
# Performance on the val set is equal to: 0.713
# Performance on the test set is equal to: 0.684
# The performance improved. New best performance = 0.713
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 180us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 180us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Number of epochs run: 15
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_15
# Performance on the train set is equal to: 0.699
# Performance on the val set is equal to: 0.713
# Performance on the test set is equal to: 0.684
# The performance improved. New best performance = 0.713
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 183us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 181us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Number of epochs run: 18
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_18
# Performance on the train set is equal to: 0.699
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.684
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 180us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 178us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Number of epochs run: 21
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_21
# Performance on the train set is equal to: 0.699
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.684
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 182us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 181us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 181us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Number of epochs run: 24
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_24
# Performance on the train set is equal to: 0.699
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.684
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 181us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 180us/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 181us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Number of epochs run: 27
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_27
# Performance on the train set is equal to: 0.699
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.684
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 180us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6939 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 178us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Number of epochs run: 30
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_30
# Performance on the train set is equal to: 0.699
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.684
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 182us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Number of epochs run: 33
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_33
# Performance on the train set is equal to: 0.699
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.684
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Number of epochs run: 36
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_36
# Performance on the train set is equal to: 0.699
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.684
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 181us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 180us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Number of epochs run: 39
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_39
# Performance on the train set is equal to: 0.699
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.684
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 178us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 178us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 178us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Number of epochs run: 42
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_42
# Performance on the train set is equal to: 0.7
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.684
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 181us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 181us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Number of epochs run: 45
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_45
# Performance on the train set is equal to: 0.7
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.684
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 180us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Number of epochs run: 48
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_48
# Performance on the train set is equal to: 0.7
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.685
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Number of epochs run: 51
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_51
# Performance on the train set is equal to: 0.7
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.685
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 180us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Number of epochs run: 54
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_54
# Performance on the train set is equal to: 0.7
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.685
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 178us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 180us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Number of epochs run: 57
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_57
# Performance on the train set is equal to: 0.7
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.685
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Number of epochs run: 60
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_60
# Performance on the train set is equal to: 0.7
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.685
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 180us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Number of epochs run: 63
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_63
# /home/al311/python_3.6.0/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Performance on the train set is equal to: 0.7
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.685
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 182us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 180us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Number of epochs run: 66
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_66
# /home/al311/python_3.6.0/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Performance on the train set is equal to: 0.7
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.685
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 180us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Number of epochs run: 69
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_69
# /home/al311/python_3.6.0/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Performance on the train set is equal to: 0.7
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.685
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 183us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 181us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 180us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Number of epochs run: 72
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_72
# /home/al311/python_3.6.0/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Performance on the train set is equal to: 0.7
# Performance on the val set is equal to: 0.714
# Performance on the test set is equal to: 0.685
# The performance improved. New best performance = 0.714
# Train on 23455 samples, validate on 2932 samples
# Epoch 1/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 2/3
# 23455/23455 [==============================] - 4s 178us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Epoch 3/3
# 23455/23455 [==============================] - 4s 179us/step - loss: 0.6924 - binary_accuracy: 0.5161 - val_loss: 0.6938 - val_binary_accuracy: 0.4945
# Number of epochs run: 75
# Version: Sex_GRU_n_layers_8_n_nodes_4_optimizer_RMSprop_learning_rate_5_input_length_10_batch_size_1024_n_epochs_run_75
# /home/al311/python_3.6.0/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Performance on the train set is equal to: 0.7
# Performance on the val set is equal to: 0.715
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-50429b2d9b0f> in <module>
#      10     print('Version: ' + version)
#      11     plot_training(history, target, hyperparameters, version, n_epochs)
# ---> 12     generate_predictions_and_compute_performances(model, hyperparameters, X_train, X_val, X_test, y_train, y_val, y_test, target, version)
#      13     if hyperparameters['Performance_val'] > Best_performance:
#      14         Best_performance = hyperparameters['Performance_val']
#
# /n/groups/patel/Alan/Aging/ECG/scripts/ECG_helpers_tf.py in generate_predictions_and_compute_performances(model, hyperparameters, X_train, X_val, X_test, y_train, y_val, y_test, target, version)
#      70 def generate_predictions_and_compute_performances(model, hyperparameters, X_train, X_val, X_test, y_train, y_val, y_test, target, version):
#      71     for fold in folds:
# ---> 72         globals()['pred_' + fold] = model.predict(locals()['X_' + fold]).squeeze()
#      73         np.save(path_compute + '/predictions/pred_' + version + '_' + fold, globals()['pred_' + fold])
#      74         if target == 'Age':
#
# ~/python_3.6.0/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# ~/python_3.6.0/lib/python3.6/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~/python_3.6.0/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/python_3.6.0/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/python_3.6.0/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
#save model
save_model(model, target, version)
# Out:
# Model's architecture for LSTM was saved.
# Model's weights for LSTM were saved.
